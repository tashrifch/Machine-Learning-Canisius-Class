# %% [markdown]
# This is the MNIST digit problem, but using the Tensor Flow system instead of the scikit-learn version
#
# Tensorflow is the package from Google for machine learning,  the most common pro level tool for ML
#
# The other prominent package for machine learning is called pytorch, we may look at that package later in the semester.  Tensorflow is more common for applications,  pytorch is more of an R&D
# tool

# %%
from tensorflow.keras.datasets import mnist

[train_images,train_labels],[test_images,test_labels]=mnist.load_data(path="D:\\Example_data\\MNIST\mnist.npz")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Note the different storage format, as 28 by 28 images,  not flat arrays this time

# %% [markdown]
# # Building an ML model using the Keras sequential model
# we define the model,  called network here,  with the line models.Sequential()
#
# and then we add layers to it,   specifying the numbers of neuron in the layer, the activation function and the size of the input data in the first layer
#
# in the output layer, we are using a softmax activation,  so the outputs scale from 0 to 1, and sum to one
#
# Notice how much control we have on the model using the keras API in tensorflow to construct the model

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

network=models.Sequential()
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# Below is a deeper alternative model,   don't run this cell the first time through the notebook,   come back to this book when
# you reach the end and run it from here to see a more complex model in action

# %%
# alternative model- don't run this the first time!   This model adds another layer,  reducing the size of the first layer

network=models.Sequential()
network.add(layers.Dense(128,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(8,activation='relu'))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# This is the set of instructions on how we want to see the model fitted.   The loss function and optimizer are specified here
# and we can also indicate that we want performance metrics calculated as this model is trained

# %%
network.compile(optimizer='rmsprop',
               loss='categorical_crossentropy',
               metrics=['accuracy','AUC'])

# %% [markdown]
# We are using a keras utility to convert the test labels to onehot encodings

# %%
from tensorflow.keras.utils import to_categorical

test_labels=to_categorical(test_labels)
train_labels=to_categorical(train_labels)

# %%
test_labels.shape
# Out:
# (10000, 10)

# %% [markdown]
# We are going to reshape the images to the flat form,and also rescale them to the range 0 to 1,  and also convert them to 32 bit float to save a bit of space

# %%
train_images=train_images.reshape(60000,28*28)
train_images=train_images.astype('float32')/255

# %% [markdown]
# We will now split the training set into a test set 2 and a validation set.   We will fit the model using the second training set and use the validation set to test
# the models during the model adjustment process

# %%
from sklearn.model_selection import train_test_split

X_train2, X_valid, y_train2, y_valid = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
print(X_train2.shape)
print(X_valid.shape)
print(y_train2.shape)
print(y_valid.shape)
# Out:
# (48000, 784)
# (12000, 784)
# (48000, 10)
# (12000, 10)

# %%
print(train_images.shape)
# Out:
# (60000, 784)

# %% [markdown]
# # Model fitting
#
# here is the model fitting process, running for 30 epochs, with a batch size of 512 points
#
# The validation set will be used at the end of each epoch, and the metrics reported
#
# The metrics will all be stored in history

# %%
history=network.fit(X_train2,y_train2,epochs=30,batch_size=512, validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/30
# 94/94 [==============================] - 3s 26ms/step - loss: 0.4568 - accuracy: 0.8735 - auc: 0.9882 - val_loss: 0.2465 - val_accuracy: 0.9299 - val_auc: 0.9952
# Epoch 2/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.2119 - accuracy: 0.9401 - auc: 0.9962 - val_loss: 0.1892 - val_accuracy: 0.9439 - val_auc: 0.9966
# Epoch 3/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.1515 - accuracy: 0.9574 - auc: 0.9977 - val_loss: 0.1379 - val_accuracy: 0.9618 - val_auc: 0.9979
# Epoch 4/30
# 94/94 [==============================] - 2s 22ms/step - loss: 0.1177 - accuracy: 0.9674 - auc: 0.9985 - val_loss: 0.1173 - val_accuracy: 0.9670 - val_auc: 0.9985
# Epoch 5/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.0938 - accuracy: 0.9740 - auc: 0.9989 - val_loss: 0.1141 - val_accuracy: 0.9652 - val_auc: 0.9984
# Epoch 6/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0769 - accuracy: 0.9778 - auc: 0.9992 - val_loss: 0.0978 - val_accuracy: 0.9709 - val_auc: 0.9987
# Epoch 7/30
# 94/94 [==============================] - 2s 22ms/step - loss: 0.0650 - accuracy: 0.9817 - auc: 0.9995 - val_loss: 0.0868 - val_accuracy: 0.9744 - val_auc: 0.9989
# Epoch 8/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0547 - accuracy: 0.9850 - auc: 0.9996 - val_loss: 0.0830 - val_accuracy: 0.9761 - val_auc: 0.9989
# Epoch 9/30
# 94/94 [==============================] - 2s 22ms/step - loss: 0.0461 - accuracy: 0.9874 - auc: 0.9997 - val_loss: 0.0815 - val_accuracy: 0.9751 - val_auc: 0.9990
# Epoch 10/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.0399 - accuracy: 0.9898 - auc: 0.9998 - val_loss: 0.0774 - val_accuracy: 0.9772 - val_auc: 0.9987
# Epoch 11/30
# 94/94 [==============================] - 2s 25ms/step - loss: 0.0342 - accuracy: 0.9914 - auc: 0.9999 - val_loss: 0.0756 - val_accuracy: 0.9775 - val_auc: 0.9988
# Epoch 12/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0290 - accuracy: 0.9933 - auc: 0.9999 - val_loss: 0.0719 - val_accuracy: 0.9783 - val_auc: 0.9990
# Epoch 13/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0254 - accuracy: 0.9940 - auc: 0.9999 - val_loss: 0.0718 - val_accuracy: 0.9780 - val_auc: 0.9988
# Epoch 14/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0215 - accuracy: 0.9952 - auc: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9787 - val_auc: 0.9985
# Epoch 15/30
# 94/94 [==============================] - 3s 27ms/step - loss: 0.0181 - accuracy: 0.9966 - auc: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9800 - val_auc: 0.9987
# Epoch 16/30
# 94/94 [==============================] - 3s 29ms/step - loss: 0.0159 - accuracy: 0.9970 - auc: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9798 - val_auc: 0.9987
# Epoch 17/30
# 94/94 [==============================] - 2s 24ms/step - loss: 0.0134 - accuracy: 0.9976 - auc: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9804 - val_auc: 0.9985
# Epoch 18/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0114 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9791 - val_auc: 0.9982
# Epoch 19/30
# 94/94 [==============================] - 2s 24ms/step - loss: 0.0098 - accuracy: 0.9986 - auc: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9804 - val_auc: 0.9983
# Epoch 20/30
# 94/94 [==============================] - 2s 24ms/step - loss: 0.0083 - accuracy: 0.9989 - auc: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9769 - val_auc: 0.9982
# Epoch 21/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.0072 - accuracy: 0.9991 - auc: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9803 - val_auc: 0.9981
# Epoch 22/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0060 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9818 - val_auc: 0.9982
# Epoch 23/30
# 94/94 [==============================] - 3s 29ms/step - loss: 0.0053 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9812 - val_auc: 0.9981
# Epoch 24/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0045 - accuracy: 0.9997 - auc: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9817 - val_auc: 0.9981
# Epoch 25/30
# 94/94 [==============================] - 2s 24ms/step - loss: 0.0039 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9806 - val_auc: 0.9980
# Epoch 26/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.0033 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9818 - val_auc: 0.9981
# Epoch 27/30
# 94/94 [==============================] - 2s 22ms/step - loss: 0.0031 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9821 - val_auc: 0.9980
# Epoch 28/30
# 94/94 [==============================] - 2s 22ms/step - loss: 0.0026 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9812 - val_auc: 0.9979
# Epoch 29/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0023 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9819 - val_auc: 0.9980
# Epoch 30/30
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0021 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9816 - val_auc: 0.9978

# %%
test_loss,test_accuracy,test_AUC=network.evaluate(X_train2,y_train2)
print('test acc:',test_accuracy)
# Out:
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - auc: 1.0000
# test acc: 1.0

# %%
print('test AUC',test_AUC)
# Out:
# test AUC 1.0

# %% [markdown]
# # Question
#
# This is the MNIST digits problem, using a bit more advanced neural net than we did with data set
# earlier.
#
# But what is claimed performance level look like?    How does it compare with your earlier results?   Is this reasonable?

# %% [markdown]
# # Now some plots using the history
#
# We can look at the loss function for the training data and the loss function for the cross validation level as a function of the number of training epochs run.
#
# Note that this notebook has two different models, watch what changes the second time we run this
# notebook using the more complex model.

# %%
import matplotlib.pyplot as plt
history_dict=history.history
loss_values=history_dict['loss']
val_loss_values=history_dict['val_loss']
epoch=range(1,len(loss_values)+1)

plt.plot(epoch,loss_values,label='Training Loss')
plt.plot(epoch,val_loss_values,label="Validation_Loss")
plt.title("Traing and Validation loss")
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
AUC=history_dict['auc']
val_AUC=history_dict['val_auc']


plt.plot(epoch,AUC,label='Training AUC')
plt.plot(epoch,val_AUC,label="Validation AUC")
plt.title("Traing and Validation AUC")
plt.xlabel("epochs")
plt.ylabel("AUC")
plt.legend()
plt.show()

# %%
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'auc', 'val_loss', 'val_accuracy', 'val_auc'])

# %%
ACC=history_dict['accuracy']
val_ACC=history_dict['val_accuracy']


plt.plot(epoch,ACC,label='Training Accuracy')
plt.plot(epoch,val_AUC,label="Validation Accuracy")
plt.title("Traing and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
